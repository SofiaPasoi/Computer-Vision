# %%
from matplotlib import pyplot as plt
from decimal import Decimal
from PIL import Image
import numpy as np
import sys
from matplotlib import rc
from matplotlib import image as mpimg

def isColored(img, rows, columns):
    if(len(img.shape)==3):
        return True
    elif(len(img.shape)==2):
        return False

def imageProccessing(img, rows, columns):
    colored= np.zeros([rows,columns])
    if(isColored(img, rows, columns)):  
        img= Decimal(img)
        for m in range (0, rows):
            for n in range (0, columns):
                colored[m][n]=(img[m][n][0]+img[m][n][1]+img[m][n][2])/3 
        return colored
    else: 
        return img

def thresholding(new_image, rows,columns, threshold):
    timage= np.zeros([rows,columns])
    
    for m in range (0,rows):
        for n in range (0,columns):
            pixelValue=new_image[m,n]
            if(pixelValue<=threshold):
                timage[m,n]=0  
            else:
                timage[m,n]=255 
    return timage

def printImage(thr,s1, threshold):
    plt.ylim(thr.shape[0],0)
    plt.xlim(0, thr.shape[1])
    plt.subplots_adjust(left=0.1, bottom=0.19, right=0.9, top=0.96)
    s="threshold: " + str(threshold)
    plt.xlabel(s)
    plt.imshow(thr,cmap="gray")
    plt.show()    
    I8 = thr.astype(np.uint8)
    img = Image.fromarray(I8)
    img.save(s1)

# %%
def main():
    img=np.array(Image.open("/home/adminn/Desktop/ask1.png") )
    img.__class__
    rows=img.shape[0]
    columns = img.shape[1]
    str="0out.png"
    threshold=45
    if(threshold>=0 and threshold<=255):
        new_image=imageProccessing(img, rows, columns)
        thr=thresholding(new_image, rows,columns, threshold)
        printImage(thr,str, threshold)
        

main()

# %%
def main():
    img=np.array(Image.open("/home/adminn/Desktop/ask1.png") )
    img.__class__
    rows=img.shape[0]
    columns = img.shape[1]
    str="1out.png"
    threshold=90
    if(threshold>=0 and threshold<=255):
        new_image=imageProccessing(img, rows, columns)
        thr=thresholding(new_image, rows,columns, threshold)
        printImage(thr,str, threshold)
        

main()

# %%
def main():
    img=np.array(Image.open("/home/adminn/Desktop/ask1.png") )
    img.__class__
    rows=img.shape[0]
    columns = img.shape[1]
    str="2out.png"
    threshold=135
    if(threshold>=0 and threshold<=255):
        new_image=imageProccessing(img, rows, columns)
        thr=thresholding(new_image, rows,columns, threshold)
        printImage(thr,str, threshold)
        

main()

# %%
def main():
    img=np.array(Image.open("/home/adminn/Desktop/ask1.png") )
    img.__class__
    rows=img.shape[0]
    columns = img.shape[1]
    str="3out.png"
    threshold=180
    if(threshold>=0 and threshold<=255):
        new_image=imageProccessing(img, rows, columns)
        thr=thresholding(new_image, rows,columns, threshold)
        printImage(thr,str, threshold)
        

main()

# %%
def main():
    img=np.array(Image.open("/home/adminn/Desktop/ask1.png") )
    img.__class__
    rows=img.shape[0]
    columns = img.shape[1]
    str="4out.png"
    threshold=225
    if(threshold>=0 and threshold<=255):
        new_image=imageProccessing(img, rows, columns)
        thr=thresholding(new_image, rows,columns, threshold)
        printImage(thr,str, threshold)
        

main()
